# %%
import pandas as pd
# %xmode Context
# Out:
# Exception reporting mode: Context

# %% [markdown]
# # Aufgabe 9
# ## Aufgabe 9.1
# <br> Funktionen: <br>

# %% [markdown]
# Nach Anfangsbuchstaben extrahieren: `col.startswith("A")` <br>
# Spalten löschen: `b.drop("`Spalte`")` <br>
# Datum ISO Format: `pd.to_datetime(`b["Spalte"]`)` <br>
# Mit Zeiträumen rechnen: `pd.to_timedelta(`b['Woche']`, unit='w')` <br> UNITS:
#
# M - Monate,
# Y - Jahre,
# w - Wochen,
# d - Tage,
# h - Stunden,
# m oder min - Minuten,
# s - Sekunden

# %%
b = pd.read_csv('../data/Aufgaben/billboard.csv')

# %%
b.sample(5)
# Out:
#      year            artist             track  time date.entered  wk1   wk2  \
# 17   2000         Anastacia    I'm Outta Love  4:01   2000-04-01   92   NaN
# 198  2000  McBride, Martina     There You Are  3:26   2000-09-09   79  75.0
# 132  2000             Ideal          Whatever  3:48   2000-06-10   75  75.0
# 286  2000   Third Eye Blind  Never Let You Go  3:57   2000-01-22   65  32.0
# 137  2000     Jackson, Alan   It Must Be Love  2:53   2000-06-24   76  74.0
#
#       wk3   wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 17    NaN  95.0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 198  75.0  75.0  73.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 132  67.0  73.0  64.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 286  25.0  24.0  23.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 137  68.0  63.0  57.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      wk75  wk76
# 17    NaN   NaN
# 198   NaN   NaN
# ...

# %%
wk_columns = [col for col in b.columns if col.startswith('wk')]

# %%
b['Woche'] = b[wk_columns].notna().sum(axis=1)

# %%
b = b.drop(columns=wk_columns)

# %%
b =b.rename(columns={'date.entered': 'start-date'})

# %%
b.head()
# Out:
#    year        artist                    track  time  start-date  Woche
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22  2000-02-26      7
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15  2000-09-02      3
# 2  2000  3 Doors Down               Kryptonite  3:53  2000-04-08     53
# 3  2000  3 Doors Down                    Loser  4:24  2000-10-21     20
# 4  2000      504 Boyz            Wobble Wobble  3:35  2000-04-15     18

# %%
b['end-date'] = pd.to_datetime(b['start-date']) + pd.to_timedelta(b['Woche'], unit='w')

# %%
b.sample(5)
# Out:
#      year            artist                    track  time  start-date  Woche  \
# 231  2000        Papa Roach              Last Resort  3:19  2000-07-29     20
# 94   2000            Eminem             The Way I Am  4:40  2000-08-26     10
# 291  2000             Train            Meet Virginia  3:55  1999-10-09     27
# 127  2000  Houston, Whitney  I Learned From The B...  4:18  2000-02-19     11
# 33   2000         Black Rob                    Whoa!  4:04  2000-03-04     17
#
#       end-date
# 231 2000-12-16
# 94  2000-11-04
# 291 2000-04-15
# 127 2000-05-06
# 33  2000-07-01

# %% [markdown]
# ## Aufgabe 9.2

# %%
data = {
    "name": ["Philipp Woods", "Philipp Woods", "Philipp Woods", "Jessica Cordero", "Jessica Cordero"],
    "property": ["age", "height", "age", "age", "height"],
    "values": [45, 186, 50, 37, 156]
}

df = pd.DataFrame(data)
df
# Out:
#               name property  values
# 0    Philipp Woods      age      45
# 1    Philipp Woods   height     186
# 2    Philipp Woods      age      50
# 3  Jessica Cordero      age      37
# 4  Jessica Cordero   height     156

# %%
df = df.pivot_table(index='name', columns='property', values='values')

# %%
df
# Out:
# property          age  height
# name
# Jessica Cordero  37.0   156.0
# Philipp Woods    47.5   186.0

# %% [markdown]
# ## 9.3

# %%
df_wide = pd.DataFrame({
    'pregnant': ['yes', 'no'],
    'male': [None, 20],
    'female': [10, 12]
})
df_wide
# Out:
#   pregnant  male  female
# 0      yes   NaN      10
# 1       no  20.0      12

# %%
df_wide.melt(id_vars='pregnant', var_name='sex', value_vars=['male','female'], value_name='count')
# Out:
#   pregnant     sex  count
# 0      yes    male    NaN
# 1       no    male   20.0
# 2      yes  female   10.0
# 3       no  female   12.0

# %% [markdown]
# ## 9.4

# %%
ts = pd.read_csv('../data/Aufgaben/country_timeseries.csv')

# %%
ts.sample(3)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 95   5/7/2014   46         236.0           13.0                0.0
# 65   8/9/2014  140         506.0          599.0              730.0
# 45  10/1/2014  193        1199.0         3834.0             2437.0
#
#     Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 95            NaN            NaN                 NaN          NaN         NaN
# 65           13.0            NaN                 NaN          NaN         NaN
# 45           20.0            1.0                 1.0          NaN         NaN
#
#     Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# 95          158.0            11.0                 0.0             NaN
# 65          373.0           323.0               315.0             2.0
# 45          739.0          2069.0               623.0             8.0
#
#     Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  Deaths_Mali
# ...

# %%
ts_cases = ts.melt(id_vars=['Date', 'Day'], var_name='Countrys_Cases', value_name='Number of Cases', value_vars=[col for col in ts.columns if 'Cases' in col] )

# %%
ts_cases.shape
# Out:
# (976, 4)

# %%
ts_deaths = ts.melt(id_vars=['Date', 'Day'], var_name='Countrys_Death', value_name='Number of Deaths', value_vars=[col for col in ts.columns if 'Deaths_' in col] )

# %%
ts_deaths.shape
# Out:
# (976, 4)

# %%
ts = ts_cases.merge(ts_deaths, on=['Date', 'Day'])

# %%
ts.head()
# Out:
#        Date  Day Countrys_Cases  Number of Cases      Countrys_Death  \
# 0  1/5/2015  289   Cases_Guinea           2776.0       Deaths_Guinea
# 1  1/5/2015  289   Cases_Guinea           2776.0      Deaths_Liberia
# 2  1/5/2015  289   Cases_Guinea           2776.0  Deaths_SierraLeone
# 3  1/5/2015  289   Cases_Guinea           2776.0      Deaths_Nigeria
# 4  1/5/2015  289   Cases_Guinea           2776.0      Deaths_Senegal
#
#    Number of Deaths
# 0            1786.0
# 1               NaN
# 2            2977.0
# 3               NaN
# 4               NaN

# %%
ts['Deaths-per-Case'] = ts['Number of Cases'] / ts['Number of Deaths']

# %%
ts['Deaths-per-Case'].notna().sum()
# Out:
# 1522

# %%
ts.shape
# Out:
# (7808, 7)

# %%
ts.head()
# Out:
#        Date  Day Countrys_Cases  Number of Cases      Countrys_Death  \
# 0  1/5/2015  289   Cases_Guinea           2776.0       Deaths_Guinea
# 1  1/5/2015  289   Cases_Guinea           2776.0      Deaths_Liberia
# 2  1/5/2015  289   Cases_Guinea           2776.0  Deaths_SierraLeone
# 3  1/5/2015  289   Cases_Guinea           2776.0      Deaths_Nigeria
# 4  1/5/2015  289   Cases_Guinea           2776.0      Deaths_Senegal
#
#    Number of Deaths  Deaths-per-Case
# 0            1786.0         1.554311
# 1               NaN              NaN
# 2            2977.0         0.932482
# 3               NaN              NaN
# 4               NaN              NaN

# %% [markdown]
# ## 9.5

# %%
w = pd.read_csv('../data/Aufgaben/weather.csv')

# %%
w.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
w.shape
# Out:
# (22, 35)

# %%
w['id'].loc[w['id']=='MX17004'].count()
# Out:
# 22

# %%
w_melted = w.melt(id_vars=['id', 'year', 'month', 'element'], value_name='value', var_name='days')

# %%
w_melted['days'] = w_melted['days'].str.extract('(\d+)').astype(int)

# %%
w_melted.dtypes
# Out:
# id          object
# year         int64
# month        int64
# element     object
# days         int64
# value      float64
# dtype: object

# %%
w_melted.sample(10)
# Out:
#           id  year  month element  days  value
# 213  MX17004  2010      8    tmin    10    NaN
# 472  MX17004  2010      6    tmax    22    NaN
# 283  MX17004  2010     11    tmin    13    NaN
# 176  MX17004  2010      1    tmax     9    NaN
# 563  MX17004  2010      7    tmin    26    NaN
# 443  MX17004  2010      2    tmin    21    NaN
# 664  MX17004  2010      3    tmax    31    NaN
# 221  MX17004  2010      1    tmin    11    NaN
# 64   MX17004  2010     12    tmax     3    NaN
# 506  MX17004  2010      1    tmax    24    NaN

# %%
w = w_melted.pivot_table(index=['id', 'year','month', 'days'], columns=['element'], values='value')

# %%
w.head()
# Out:
# element                  tmax  tmin
# id      year month days
# MX17004 2010 1     30    27.8  14.5
#              2     2     27.3  14.4
#                    3     24.1  14.4
#                    11    29.7  13.4
#                    23    29.9  10.7

# %%
w.columns.get_level_values(0)
# Out:
# Index(['tmax', 'tmin'], dtype='object', name='element')

# %%
w = w.sort_values(['month', 'days'])

# %%
w = w.reset_index()

# %%
w.head()
# Out:
# element       id  year  month  days  tmax  tmin
# 0        MX17004  2010      1    30  27.8  14.5
# 1        MX17004  2010      2     2  27.3  14.4
# 2        MX17004  2010      2     3  24.1  14.4
# 3        MX17004  2010      2    11  29.7  13.4
# 4        MX17004  2010      2    23  29.9  10.7

# %%
w['Date'] = pd.to_datetime(w[['year', 'month', 'days']])

# %%
# w['Date'] = pd.to_datetime(w['year'].astype(str) + '-' + w['month'].astype(str) + '-' + w['days'].astype(str))

# %%
w.head()
# Out:
# element       id  year  month  days  tmax  tmin       Date
# 0        MX17004  2010      1    30  27.8  14.5 2010-01-30
# 1        MX17004  2010      2     2  27.3  14.4 2010-02-02
# 2        MX17004  2010      2     3  24.1  14.4 2010-02-03
# 3        MX17004  2010      2    11  29.7  13.4 2010-02-11
# 4        MX17004  2010      2    23  29.9  10.7 2010-02-23
