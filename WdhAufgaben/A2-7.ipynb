# %%
import pandas as pd
import os
# %xmode minimal
# Out:
# Exception reporting mode: Minimal

# %%
url = 'https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv'
file = '../data/titanic_2_original.pickle' # Damit es local gespeichert wird

if os.path.exists(file):
    t = pd.read_pickle(file)
else:
    t = pd.read_csv(url)
    t.to_pickle(file)
t.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 615          616         1       2
# 505          506         0       1
# 535          536         1       2
# 162          163         0       3
# 167          168         0       3
# 525          526         0       3
# 393          394         1       1
# 469          470         1       3
# 555          556         0       1
# 236          237         0       2
#
#                                                 Name     Sex    Age  SibSp  \
# 615                              Herman, Miss. Alice  female  24.00      1
# 505       Penasco y Castellana, Mr. Victor de Satode    male  18.00      1
# 535                           Hart, Miss. Eva Miriam  female   7.00      0
# 162                       Bengtsson, Mr. John Viktor    male  26.00      0
# 167  Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.00      1
# 525                               Farrell, Mr. James    male  40.50      0
# ...

# %% [markdown]
# # Aufgabe 7
# ## Aufgabe 7.1

# %% [markdown]
# a)

# %%
t.loc[t['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# b)

# %%
t['Age'].isnull().sum()
# Out:
# 177

# %% [markdown]
# c)

# %%
t.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# d)

# %%
t.isnull().any(axis=1).sum()
# Out:
# 708

# %% [markdown]
# ## Aufgabe 7.2

# %% [markdown]
# a)

# %%
median = t['Age'].median()

# %%
t_median = t['Age'].fillna(median)

# %% [markdown]
# b) <br>
# Funktion <br>
# komplexe Transformationen auf Daten in einem DataFrame anzuwenden, oft in Verbindung mit der groupby-Methode. <br>
# `group.transform('median) `

# %%
t.loc[t['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
t_class_median = t.groupby('Pclass')['Age'].transform('median')

# %%
t['Age'] = t['Age'].fillna(t_class_median)

# %%
t.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
t.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  24.0      0
# ...

# %%
t.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                        24.0
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %% [markdown]
# c) <br>
# Funktionen: <br>
# `isna()` und `notna()`

# %%
t['Embarked'].isna().sum()
# Out:
# 2

# %%
t.loc[t['Embarked'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
t = t.loc[t['Embarked'].notna()]

# %%
t.loc[t['Embarked'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# d) --> Es wurden zwei gelöscht siehe c)

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def gender(v):
    if v == 'female': return 'f'
    if v == 'male': return 'm'

# %%
t['Sex'] = t['Sex'].map(gender)

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   m  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0      1      0
# 2                             Heikkinen, Miss. Laina   f  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0      1      0
# 4                           Allen, Mr. William Henry   m  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
t['Sex'].map({'m':'male', 'f':'female'})
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 889, dtype: object

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   m  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0      1      0
# 2                             Heikkinen, Miss. Laina   f  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   f  35.0      1      0
# 4                           Allen, Mr. William Henry   m  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
