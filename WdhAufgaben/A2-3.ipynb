# %%
import pandas as pd
import os

# %%
url = 'https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv'
file = '../data/titanic_2_original.pickle' # Damit es local gespeichert wird

if os.path.exists(file):
    t = pd.read_pickle(file)
else:
    t = pd.read_csv(url)
    t.to_pickle(file)
t.sample(10)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 882          883         0       3       Dahlberg, Miss. Gerda Ulrika  female
# 720          721         1       2  Harper, Miss. Annie Jessie "Nina"  female
# 584          585         0       3                Paulner, Mr. Uscher    male
# 786          787         1       3          Sjoblom, Miss. Anna Sofia  female
# 727          728         1       3           Mannion, Miss. Margareth  female
# 884          885         0       3             Sutehall, Mr. Henry Jr    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 393          394         1       1             Newell, Miss. Marjorie  female
# 24            25         0       3      Palsson, Miss. Torborg Danira  female
# 479          480         1       3           Hirvonen, Miss. Hildur E  female
#
#       Age  SibSp  Parch           Ticket      Fare Cabin Embarked
# ...

# %%
url = 'https://hbiostat.org/data/repo/titanic5.xlsx'
file = '../data/titanic_original.pickle' # Damit es local gespeichert wird

if os.path.exists(file):
    t2 = pd.read_pickle(file)
else:
    t2 = pd.read_excel(url, sheet_name='Titanic5_all')#, dtype_backend='numpy_nullable')
    t2.to_pickle(file)
t2.sample(2)
# Out:
#       Name_ID                          Name  Female  Male     Sex   Age  \
# 1769     1856  SKOOG, Mr Wilhelm Johansson        0     1    male  40.0
# 1011     1266         MARSDEN, Miss Evelyn        1     0  female  28.0
#
#                Class/Dept Class  Ticket       Joined  ... Title  \
# 1769  3rd Class Passenger     3  347088  Southampton  ...    Mr
# 1011     Victualling Crew     V     NaN  Southampton  ...  Miss
#
#                   First        DoB Year_Birth           Date_Death  \
# 1769  Wilhelm Johansson 1872-04-06        NaN  1912-04-15 00:00:00
# 1011             Evelyn 1883-10-15        NaN  1938-08-30 00:00:00
#
#        DoB_Clean Age_F_Code Age_F sibsp parch
# 1769    4/6/1872          C  40.0   1.0   4.0
# 1011  10/15/1883          C  28.0   NaN   NaN
#
# [2 rows x 27 columns]

# %%
t['Cabin'] = t['Cabin'].str.lower()

# %%
t['Cabin'] = t['Cabin'].map(lambda s: s.str.lower())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t['Cabin'] = t['Cabin'].map(lambda s: s.str.lower())
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4537     dtype: object
#    4538     """
# -> 4539     new_values = self._map_values(arg, na_action=na_action)
#    4540     return self._constructor(new_values, index=self.index).__finalize__(
#    4541         self, method="map"
#    4542     )
#
# ...

# %%
t.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ## 3.2

# %%
t.sample(4)
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 740          741         1       1  Hawksford, Mr. Walter James    male   NaN
# 580          581         1       2  Christy, Miss. Julie Rachel  female  25.0
# 456          457         0       1    Millet, Mr. Francis Davis    male  65.0
# 666          667         0       2  Butler, Mr. Reginald Fenton    male  25.0
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked
# 740      0      0   16988  30.00   d45        S
# 580      1      1  237789  30.00   NaN        S
# 456      0      0   13509  26.55   e38        S
# 666      0      0  234686  13.00   NaN        S

# %%
import re

# %%
t['Nachname'] = t['Name'].str.extract(r'^([^,]+)')

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Nachname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   c85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  c123        S   Futrelle
# ...
